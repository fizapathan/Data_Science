# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/oivx7uber6tnywazctti7smg6fv5hr')

# %%
df
# Out:
#       avganncount  avgdeathsperyear  target_deathrate  incidencerate  \
# 0     1397.000000               469             164.9     489.800000
# 1      173.000000                70             161.3     411.600000
# 2      102.000000                50             174.7     349.700000
# 3      427.000000               202             194.8     430.400000
# 4       57.000000                26             144.4     350.100000
# 5      428.000000               152             176.0     505.400000
# 6      250.000000                97             175.9     461.800000
# 7      146.000000                71             183.6     404.000000
# 8       88.000000                36             190.5     459.400000
# 9     4025.000000              1380             177.8     510.900000
# 10     113.000000                36             121.4     413.300000
# 11     740.000000               269             172.7     499.300000
# 12      55.000000                26             188.3     398.900000
# ...

# %%
df.fillna(0, inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
corr = df.corr()

# %%
corr
# Out:
#                          avganncount  avgdeathsperyear  target_deathrate  \
# avganncount                 1.000000          0.939408         -0.143532
# avgdeathsperyear            0.939408          1.000000         -0.090715
# target_deathrate           -0.143532         -0.090715          1.000000
# incidencerate               0.073553          0.062690          0.449432
# medincome                   0.269145          0.223207         -0.428615
# popest2015                  0.926894          0.977634         -0.120073
# povertypercent             -0.135694         -0.066918          0.429389
# studypercap                 0.082071          0.063488         -0.022285
# medianage                  -0.024098         -0.024599          0.004375
# medianagemale              -0.124969         -0.148487         -0.021929
# medianagefemale            -0.122844         -0.144069          0.012048
# percentmarried             -0.106108         -0.181029         -0.266820
# ...

# %%
max(corr)
# Out:
# 'target_deathrate'

# %%
x = df['target_deathrate']

# %%
y = df['pctbachdeg25_over']

# %%
x
# Out:
# 0       164.9
# 1       161.3
# 2       174.7
# 3       194.8
# 4       144.4
# 5       176.0
# 6       175.9
# 7       183.6
# 8       190.5
# 9       177.8
# 10      121.4
# 11      172.7
# 12      188.3
# 13      165.3
# 14      171.0
# 15      174.2
# 16      169.9
# 17      153.8
# 18      162.8
# 19      163.3
# 20      140.8
# 21      169.4
# 22      189.7
# 23      206.1
# 24      236.7
# 25      196.3
# 26      186.2
# 27      194.0
# 28      226.5
# 29      212.9
#         ...
# 3017    159.3
# 3018    196.4
# 3019    174.8
# 3020    180.2
# 3021    197.8
# 3022    178.3
# 3023    166.6
# 3024    184.2
# 3025    175.0
# 3026    177.8
# 3027    194.2
# 3028    150.0
# 3029    153.7
# 3030    169.2
# 3031    178.6
# 3032    176.6
# 3033    209.6
# 3034    184.4
# 3035    214.7
# 3036    181.2
# 3037    160.3
# 3038    153.7
# 3039    208.3
# 3040    215.9
# 3041    146.4
# 3042    149.6
# 3043    150.1
# 3044    153.9
# 3045    175.0
# 3046    213.6
# ...

# %%
y
# Out:
# 0       19.6
# 1       22.7
# 2       16.0
# 3        9.3
# 4       15.0
# 5       11.9
# 6       11.9
# 7       11.3
# 8       12.0
# 9       16.2
# 10      26.2
# 11      15.9
# 12      14.2
# 13      20.9
# 14      18.1
# 15      10.7
# 16      20.3
# 17      10.1
# 18      16.4
# 19      21.3
# 20      25.7
# 21       9.8
# 22       7.9
# 23      12.7
# 24       5.4
# 25       8.5
# 26      11.0
# 27      14.8
# 28       7.6
# 29       5.8
#         ...
# 3017    12.1
# 3018    12.2
# 3019    10.5
# 3020    12.7
# 3021    11.7
# 3022    12.4
# 3023    13.9
# 3024    12.1
# 3025    18.6
# 3026    16.5
# 3027    13.2
# 3028    16.9
# 3029    23.5
# 3030    16.0
# 3031    10.6
# 3032    15.6
# 3033    17.2
# 3034    12.7
# 3035    18.5
# 3036    13.6
# 3037    11.3
# 3038    26.3
# 3039    15.0
# 3040    11.8
# 3041    21.9
# 3042    15.2
# 3043    12.4
# 3044    12.8
# 3045    14.4
# 3046    13.7
# Name: pctbachdeg25_over, Length: 3047, dtype: float64

# %%
import numpy as np

# %%
x = np.array(x)

# %%
x = x.reshape(-1,1)

# %%
x
# Out:
# array([[164.9],
#        [161.3],
#        [174.7],
#        ...,
#        [153.9],
#        [175. ],
#        [213.6]])

# %%
y = np.array(y)

# %%
y = y.reshape(-1,1)

# %%
y
# Out:
# array([[19.6],
#        [22.7],
#        [16. ],
#        ...,
#        [12.8],
#        [14.4],
#        [13.7]])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .20)

# %%
from sklearn.linear_model import  LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
model.predict(x_test)
# Out:
# array([[ 7.75076813],
#        [15.91631267],
#        [14.01842533],
#        [16.72175754],
#        [ 8.00073378],
#        [20.19350266],
#        [14.65722644],
#        [12.37976163],
#        [13.80549163],
#        [14.67574241],
#        [13.24075442],
#        [11.05586949],
#        [15.77744286],
#        [12.05573209],
#        [14.3980028 ],
#        [14.28690696],
#        [15.09235182],
#        [ 7.76002612],
#        [10.85219378],
#        [17.69384617],
#        [19.75837727],
#        [12.31495572],
#        [10.2689406 ],
#        [15.26825358],
#        [15.54599319],
#        [12.25014982],
#        [12.94449884],
#        [12.72230715],
#        [12.35198767],
#        [13.00004676],
#        [11.45396293],
#        [10.42632638],
#        [15.38860741],
#        [15.58302514],
#        [14.83312819],
#        [10.28745657],
#        [15.63857306],
#        [ 9.95416904],
#        [ 5.51033528],
#        [15.01828793],
#        [15.36083345],
# ...

# %%
y_train
# Out:
# array([[13.8],
#        [18.1],
#        [ 6.9],
#        ...,
#        [13.7],
#        [ 9.6],
#        [ 8.8]])

# %%
model.predict(x_train)
# Out:
# array([[16.16627832],
#        [13.58329994],
#        [14.37948683],
#        ...,
#        [16.40698598],
#        [11.87983034],
#        [11.94463624]])

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,model.predict(x_test))/100
# Out:
# 0.03706875210106556

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

ax.scatter(y_test, model.predict(x_test))
plt.xlabel("Actual Deaths due to cancer")
plt.ylabel("Predicted Deaths due to cancer")
plt.plot()
# Out:
# []
